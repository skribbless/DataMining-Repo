# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
dg = pd.read_csv('datasets//dengue.csv')

# %%
dg
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %%
dg.dtypes
# Out:
# Month            object
# Year              int64
# Region           object
# Dengue_Cases      int64
# Dengue_Deaths     int64
# dtype: object

# %%
dg.head
# Out:
# <bound method NDFrame.head of           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]>

# %%
dg.info
# Out:
# <bound method DataFrame.info of           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]>

# %%
dg.isnull().sum()
# Out:
# Month            0
# Year             0
# Region           0
# Dengue_Cases     0
# Dengue_Deaths    0
# dtype: int64

# %%
month_order = ['January','February','March','April','May','June','July','August','September','October','November','December']
dg['Month'] = pd.Categorical(dg['Month'], categories=month_order, ordered=True)

# %%
monthly_cases = dg.groupby([dg.Month, dg.Year])["Dengue_Cases"].sum()

# %%
monthly_cases.unstack().plot(kind='line')
plt.gcf().set_size_inches(12,8)
plt.grid(True)
plt.xticks(range(0,12), month_order)
plt.show()

# %% [markdown]
# <h1>Temporal Trends of Dengue Incidents</h1>

# %%
data = {'Date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05'],
        'Cases': [5, 12, 8, 7, 10]}
df = pd.DataFrame(data)

df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(10,6))
plt.plot(df['Date'], df['Cases'], marker='o', color='b')
plt.title('Dengue Incidents Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h1>Insight 2</h1>
# <p1>Correlation Between Rainfall and Dengue Incidents</p1>

# %%
data = {'Rainfall': [10, 20, 30, 40, 50], 'DengueCases': [5, 15, 20, 25, 30]}
df = pd.DataFrame(data)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Rainfall', y='DengueCases', data=df)
plt.title('Correlation Between Rainfall and Dengue Cases')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Number of Dengue Cases')
plt.show()

# Calculate correlation
correlation = df['Rainfall'].corr(df['DengueCases'])
print(f'Correlation between Rainfall and Dengue Cases: {correlation}')
# Out:
# Correlation between Rainfall and Dengue Cases: 0.9863939238321439

# %% [markdown]
# <h1>Insight 3</h1>
# <p1>Effectiveness of Public Health Interventions</p1>

# %%
data = {'Period': ['Before', 'After', 'Before', 'After', 'Before'],
        'Cases': [50, 30, 60, 40, 55]}

df = pd.DataFrame(data)
sns.boxplot(x='Period', y='Cases', data=df)
plt.title('Dengue Cases Before and After Public Health Intervention')
plt.show()

# %% [markdown]
# <h1>Insight 4</h1>
# <p1>Dengue deaths per year</p1>

# %%
df = pd.read_csv('datasets//dengue.csv')

df.head()
df_grouped = df.groupby('Year')['Deaths'].sum().reset_index()


plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='Deaths', data=df_grouped, palette='viridis')

plt.title('Dengue Deaths per Year')
plt.xlabel('Year')
plt.ylabel('Total Deaths')
plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()

print(df_grouped.describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
#       1 df = pd.read_csv('datasets//dengue.csv')
#       3 df.head()
# ----> 4 df_grouped = df.groupby('Year')['Deaths'].sum().reset_index()
#       7 plt.figure(figsize=(12, 6))
#       8 sns.barplot(x='Year', y='Deaths', data=df_grouped, palette='viridis')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...
